# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from FCPython import createPitch
import json
from pandas.io.json import json_normalize

# %%
pd.options.display.max_columns = 250 #Changes the number of columns diplayed (default is 20)
pd.options.display.max_rows = 400 #Changes the number of rows diplayed (default is 60)
pd.options.display.max_colwidth = 250 #Changes the number of characters in a cell so that the contents don't get truncated (default is 50)

# %%
# Read json and store as df
competition = pd.read_json('../open-data/data/competitions.json')
competition.head()
# Out:
#    competition_id  season_id country_name  competition_name  \
# 0              16          4       Europe  Champions League
# 1              16          1       Europe  Champions League
# 2              16          2       Europe  Champions League
# 3              16         27       Europe  Champions League
# 4              16         26       Europe  Champions League
#
#   competition_gender  competition_youth  competition_international  \
# 0               male              False                      False
# 1               male              False                      False
# 2               male              False                      False
# 3               male              False                      False
# 4               male              False                      False
#
#   season_name               match_updated        match_updated_360  \
# 0   2018/2019  2023-03-07T12:20:48.118250  2021-06-13T16:17:31.694
# 1   2017/2018  2021-08-27T11:26:39.802832  2021-06-13T16:17:31.694
# 2   2016/2017  2021-08-27T11:26:39.802832  2021-06-13T16:17:31.694
# 3   2015/2016  2021-08-27T11:26:39.802832  2021-06-13T16:17:31.694
# 4   2014/2015  2021-08-27T11:26:39.802832  2021-06-13T16:17:31.694
#
#   match_available_360             match_available
# 0                None  2023-03-07T12:20:48.118250
# 1                None  2021-01-23T21:55:30.425330
# 2                None            2020-07-29T05:00
# 3                None            2020-07-29T05:00
# 4                None            2020-07-29T05:00

# %%
# Filter to just return champions league events
competition[competition.competition_name == 'FIFA World Cup']
# Out:
#     competition_id  season_id   country_name competition_name  \
# 18              43        106  International   FIFA World Cup
# 19              43          3  International   FIFA World Cup
#
#    competition_gender  competition_youth  competition_international  \
# 18               male              False                       True
# 19               male              False                       True
#
#    season_name               match_updated           match_updated_360  \
# 18        2022  2023-06-07T18:13:08.086293  2023-06-07T18:14:13.168183
# 19        2018  2022-09-05T17:17:56.670896     2021-06-13T16:17:31.694
#
#            match_available_360             match_available
# 18  2023-06-07T18:14:13.168183  2023-06-07T18:13:08.086293
# 19                        None  2022-09-05T17:17:56.670896

# %%
with open('../open-data/data/matches/43/106.json') as f:
    data = json.load(f)
    for i in data:
        print('ID:', i['match_id'], i['home_team']['home_team_name'], i['home_score'], '-', i['away_score'], i['away_team']['away_team_name'])
# Out:
# ID: 3857256 Serbia 2 - 3 Switzerland
# ID: 3869151 Argentina 2 - 1 Australia
# ID: 3857257 Australia 1 - 0 Denmark
# ID: 3857258 Brazil 2 - 0 Serbia
# ID: 3857288 Tunisia 0 - 1 Australia
# ID: 3857267 Ecuador 1 - 2 Senegal
# ID: 3869321 Netherlands 2 - 2 Argentina
# ID: 3857287 Uruguay 0 - 0 South Korea
# ID: 3869486 Morocco 1 - 0 Portugal
# ID: 3869685 Argentina 3 - 3 France
# ID: 3857260 Saudi Arabia 1 - 2 Mexico
# ID: 3857264 Poland 0 - 2 Argentina
# ID: 3857266 France 2 - 1 Denmark
# ID: 3857289 Argentina 2 - 0 Mexico
# ID: 3857269 Brazil 1 - 0 Switzerland
# ID: 3857294 Netherlands 2 - 0 Qatar
# ID: 3869254 Portugal 6 - 1 Switzerland
# ID: 3869118 England 3 - 0 Senegal
# ID: 3869684 Croatia 2 - 1 Morocco
# ID: 3869519 Argentina 3 - 0 Croatia
# ID: 3869354 England 1 - 2 France
# ID: 3869552 France 2 - 0 Morocco
# ID: 3869420 Croatia 1 - 1 Brazil
# ID: 3869220 Morocco 0 - 0 Spain
# ID: 3869219 Japan 1 - 1 Croatia
# ID: 3869253 Brazil 4 - 1 South Korea
# ID: 3869152 France 3 - 1 Poland
# ID: 3869117 Netherlands 3 - 1 United States
# ID: 3857270 Portugal 2 - 0 Uruguay
# ID: 3857263 Spain 1 - 1 Germany
# ID: 3857259 Cameroon 3 - 3 Serbia
# ID: 3857295 Japan 0 - 1 Costa Rica
# ID: 3857283 Belgium 0 - 2 Morocco
# ID: 3857284 Germany 1 - 2 Japan
# ID: 3857282 United States 1 - 1 Wales
# ID: 3857286 Qatar 0 - 2 Ecuador
# ID: 3857301 Qatar 1 - 3 Senegal
# ID: 3857300 Argentina 1 - 2 Saudi Arabia
# ID: 3857299 South Korea 2 - 3 Ghana
# ID: 3857298 Portugal 3 - 2 Ghana
# ID: 3857297 Poland 2 - 0 Saudi Arabia
# ID: 3857296 Croatia 0 - 0 Belgium
# ID: 3857293 Ghana 0 - 2 Uruguay
# ID: 3857292 Costa Rica 2 - 4 Germany
# ID: 3857291 Spain 7 - 0 Costa Rica
# ID: 3857290 Switzerland 1 - 0 Cameroon
# ID: 3857285 Senegal 0 - 2 Netherlands
# ID: 3857281 Croatia 4 - 1 Canada
# ID: 3857280 Cameroon 1 - 0 Brazil
# ID: 3857279 France 4 - 1 Australia
# ID: 3857278 Iran 0 - 1 United States
# ID: 3857277 Morocco 0 - 0 Croatia
# ID: 3857276 Canada 1 - 2 Morocco
# ID: 3857275 Tunisia 1 - 0 France
# ID: 3857274 Netherlands 1 - 1 Ecuador
# ID: 3857273 Wales 0 - 2 Iran
# ID: 3857272 England 0 - 0 United States
# ID: 3857271 England 6 - 2 Iran
# ID: 3857268 Belgium 1 - 0 Canada
# ID: 3857265 Mexico 0 - 0 Poland
# ID: 3857262 South Korea 2 - 1 Portugal
# ID: 3857261 Wales 0 - 3 England
# ID: 3857255 Japan 2 - 1 Spain
# ID: 3857254 Denmark 0 - 0 Tunisia

# %%
with open('../open-data/data/events/3857271.json') as f:
    engira = json.load(f)
    
len(engira)
# Out:
# 3649

# %%
df = pd.json_normalize(engira, sep='_').assign(match_id="3857271")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3649 entries, 0 to 3648
# Columns: 120 entries, id to match_id
# dtypes: float64(32), int64(9), object(79)
# memory usage: 3.3+ MB

# %%
shots = df[df.type_name == 'Shot'].set_index('id')
shots.head()
shots.loc[shots['shot_outcome_name'] == 'Goal', ['period', 'player_name', 'location']]
# Out:
#                                       period      player_name       location
# id
# f6ab1f9f-49b3-4159-9229-2d6468444c80       1  Jude Bellingham  [112.0, 38.0]
# fb8746d5-622f-4d58-94c4-d1b98a5383e5       1      Bukayo Saka  [104.1, 38.5]
# 87851dd9-302c-42ec-955b-812c658adf08       1  Raheem Sterling  [111.0, 42.8]
# c00d9764-b99c-4ee2-a5eb-f15a6119bc8f       2      Bukayo Saka  [105.3, 46.3]
# 792de1ce-2b57-4766-9925-36b991f4f753       2     Mehdi Taremi  [109.7, 48.0]
# 055f83c8-62eb-421d-81d0-5894c99d4f0a       2  Marcus Rashford  [109.7, 47.7]
# f4005cfd-ba86-4655-87b4-31b1980494bb       2    Jack Grealish  [112.0, 39.9]
# 2cfc5d86-7083-4975-95c7-e67c3a7439c9       2     Mehdi Taremi  [108.0, 40.0]

# %%
# %%javascript
# IPython.OutputArea.auto_scroll_threshold = 9999;

# %%
shots.columns.values
# Out:
# array(['index', 'period', 'timestamp', 'minute', 'second', 'possession',
#        'duration', 'type_id', 'type_name', 'possession_team_id',
#        'possession_team_name', 'play_pattern_id', 'play_pattern_name',
#        'team_id', 'team_name', 'tactics_formation', 'tactics_lineup',
#        'related_events', 'location', 'player_id', 'player_name',
#        'position_id', 'position_name', 'pass_recipient_id',
#        'pass_recipient_name', 'pass_length', 'pass_angle',
#        'pass_height_id', 'pass_height_name', 'pass_end_location',
#        'pass_body_part_id', 'pass_body_part_name', 'pass_type_id',
#        'pass_type_name', 'carry_end_location', 'under_pressure',
#        'pass_aerial_won', 'pass_outcome_id', 'pass_outcome_name',
#        'duel_type_id', 'duel_type_name', 'clearance_left_foot',
#        'clearance_body_part_id', 'clearance_body_part_name', 'pass_cross',
#        'ball_receipt_outcome_id', 'ball_receipt_outcome_name',
#        'clearance_aerial_won', 'clearance_head', 'out', 'pass_switch',
#        'pass_inswinging', 'pass_technique_id', 'pass_technique_name',
#        'counterpress', 'duel_outcome_id', 'duel_outcome_name',
#        'dribble_outcome_id', 'dribble_outcome_name', 'goalkeeper_type_id',
#        'goalkeeper_type_name', 'goalkeeper_outcome_id',
#        'goalkeeper_outcome_name', 'shot_statsbomb_xg',
#        'shot_end_location', 'shot_body_part_id', 'shot_body_part_name',
#        'shot_type_id', 'shot_type_name', 'shot_outcome_id',
#        'shot_outcome_name', 'shot_first_time', 'shot_technique_id',
#        'shot_technique_name', 'shot_freeze_frame',
#        'goalkeeper_end_location', 'goalkeeper_position_id',
#        'goalkeeper_position_name', 'off_camera',
#        'substitution_outcome_id', 'substitution_outcome_name',
#        'substitution_replacement_id', 'substitution_replacement_name',
#        'interception_outcome_id', 'interception_outcome_name',
#        'clearance_right_foot', 'foul_committed_card_id',
#        'foul_committed_card_name', 'foul_won_defensive',
#        'ball_recovery_recovery_failure', 'pass_assisted_shot_id',
#        'pass_shot_assist', 'shot_key_pass_id', 'goalkeeper_technique_id',
#        'goalkeeper_technique_name', 'goalkeeper_body_part_id',
#        'goalkeeper_body_part_name', 'dribble_nutmeg', 'pass_outswinging',
#        'shot_aerial_won', 'pass_goal_assist', 'foul_committed_type_id',
#        'foul_committed_type_name', 'shot_deflected', 'block_deflection',
#        'pass_deflected', 'foul_committed_advantage', 'foul_won_advantage',
#        'pass_cut_back', 'foul_committed_offensive', 'dribble_overrun',
#        'block_offensive', 'pass_through_ball', 'shot_one_on_one',
#        'shot_saved_to_post', 'goalkeeper_shot_saved_to_post',
#        'foul_committed_penalty', 'foul_won_penalty', 'match_id'],
#       dtype=object)

# %%
pitch_width = 120
pitch_height = 80

fig, ax = createPitch(pitch_width, pitch_height, 'yards', 'gray')

home_team = 'England'
away_team = 'Iran'
home_goal_positions = set()
away_goal_positions = set()

for i, shot in shots.iterrows():
    x = shot['location'][0]
    y = shot['location'][1]
    
    goal = shot['shot_outcome_name']=='Goal'
    team_name = shot['team_name']
    in_game = shot['period'] != 5
    
    circle_size = 2
    circle_size = np.sqrt(shot['shot_statsbomb_xg'] * 15)
    
    if team_name == home_team and in_game:
        if goal:
            diff = 1
            pos = (x, y)
            if pos in home_goal_positions:
                diff = -diff
            else:
                home_goal_positions.update([pos])
            shot_circle = plt.Circle((x, pitch_height-y), circle_size, facecolor='red', edgecolor='black')
            shot_circle.set_alpha(.8)
        else:
            shot_circle = plt.Circle((x, pitch_height-y), circle_size, color='red')
            shot_circle.set_alpha(.2)
    elif team_name == away_team:
        if goal:
            diff = 1
            pos = (x, y)
            if pos in away_goal_positions:
                diff = -diff
            else:
                away_goal_positions.update([pos])
            shot_circle = plt.Circle((pitch_width-x, y), circle_size, facecolor='blue', edgecolor='black')
            shot_circle.set_alpha(.8)
        else:
            shot_circle = plt.Circle((pitch_width-x, y), circle_size, color='blue')
            shot_circle.set_alpha(.2)
    
    ax.add_patch(shot_circle)
    
print(home_goal_positions)
print(away_goal_positions)
plt.text(5, 75, away_team + ' shots')
plt.text(80, 75, home_team + ' shots')

plt.title('England vs Iran at 2022 FIFA World Cup')

fig.set_size_inches(10, 7)
fig.savefig('argfra_shots.png', dpi=300) 

plt.show()
# Out:
# {(104.1, 38.5), (112.0, 39.9), (105.3, 46.3), (112.0, 38.0), (111.0, 42.8), (109.7, 47.7)}
# {(109.7, 48.0), (108.0, 40.0)}

# %%
rashford_shot = shots[shots['player_name'] == 'Bukayo Saka']

# %%
rashford_shot['location']
# Out:
# id
# 3ba35261-6891-4612-b191-d65a0d78f0a4    [101.1, 55.3]
# fb8746d5-622f-4d58-94c4-d1b98a5383e5    [104.1, 38.5]
# c00d9764-b99c-4ee2-a5eb-f15a6119bc8f    [105.3, 46.3]
# Name: location, dtype: object

# %%
pitch_width = 120
pitch_height = 80

fig, ax = createPitch(pitch_width, pitch_height, 'yards', 'gray')

for i, shot in rashford_shot.iterrows():
    x = shot['location'][0]
    y = shot['location'][1]
    print(y)
    
    goal = shot['shot_outcome_name']=='Goal'
    
    
    circle_size = 2
    circle_size = np.sqrt(shot['shot_statsbomb_xg'] * 15)
    if goal:
        shot_circle = plt.Circle((x, pitch_height-y), circle_size, facecolor='red', edgecolor='black')
        shot_circle.set_alpha(.8)
    else:
        shot_circle = plt.Circle((x, pitch_height-y), circle_size, color='red')
        shot_circle.set_alpha(.2)
    
    ax.add_patch(shot_circle)
    
print(home_goal_positions)
print(away_goal_positions)


plt.title('England vs Iran at 2022 FIFA World Cup')

fig.set_size_inches(10, 7)
fig.savefig('argfra_shots.png', dpi=300) 

plt.show()
# Out:
# 55.3
# 38.5
# 46.3
# {(104.1, 38.5), (112.0, 39.9), (105.3, 46.3), (112.0, 38.0), (111.0, 42.8), (109.7, 47.7)}
# {(109.7, 48.0), (108.0, 40.0)}

# %%
with open('../open-data/data/events/c.json') as f:
    wal_eng = json.load(f)
    
len(wal_eng)
# Out:
# 3316

# %%
we = pd.json_normalize(wal_eng, sep='_').assign(match_id="3857261")
we.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3316 entries, 0 to 3315
# Columns: 120 entries, id to match_id
# dtypes: float64(33), int64(9), object(78)
# memory usage: 3.0+ MB

# %%
we.head()
# Out:
#                                      id  index  period     timestamp  minute  \
# 0  ef50f27e-8b64-4185-ba52-2e622d7ebe38      1       1  00:00:00.000       0
# 1  87729e4d-8838-4cae-b7cb-ca8b22af6cff      2       1  00:00:00.000       0
# 2  a3f9ce51-db7f-449a-902f-f4a595330b13      3       1  00:00:00.000       0
# 3  5c4cab8f-dfac-47de-bca4-3ca4d211f915      4       1  00:00:00.000       0
# 4  285b3d0e-ed65-4f11-84ee-1ac2e6b0491e      5       1  00:00:00.371       0
#
#    second  possession  duration  type_id    type_name  possession_team_id  \
# 0       0           1     0.000       35  Starting XI                 907
# 1       0           1     0.000       35  Starting XI                 907
# 2       0           1     0.000       18   Half Start                 907
# 3       0           1     0.000       18   Half Start                 907
# 4       0           2     1.615       30         Pass                 907
#
#   possession_team_name  play_pattern_id play_pattern_name  team_id team_name  \
# 0                Wales                1      Regular Play      907     Wales
# 1                Wales                1      Regular Play      768   England
# 2                Wales                1      Regular Play      907     Wales
# 3                Wales                1      Regular Play      768   England
# 4                Wales                9     From Kick Off      907     Wales
#
#    tactics_formation  \
# 0             4231.0
# 1              433.0
# 2                NaN
# 3                NaN
# 4                NaN
#
#                                                                                                                                                                                                                                               tactics_lineup  \
# 0  [{'player': {'id': 9914, 'name': 'Danny Ward'}, 'position': {'id': 1, 'name': 'Goalkeeper'}, 'jersey_number': 12}, {'player': {'id': 34794, 'name': 'Neco Williams'}, 'position': {'id': 2, 'name': 'Right Back'}, 'jersey_number': 3}, {'player': {'i...
# 1  [{'player': {'id': 3468, 'name': 'Jordan Pickford'}, 'position': {'id': 1, 'name': 'Goalkeeper'}, 'jersey_number': 1}, {'player': {'id': 3205, 'name': 'Kyle Walker'}, 'position': {'id': 2, 'name': 'Right Back'}, 'jersey_number': 2}, {'player': {'...
# 2                                                                                                                                                                                                                                                        NaN
# 3                                                                                                                                                                                                                                                        NaN
# 4                                                                                                                                                                                                                                                        NaN
#
#                            related_events      location  player_id  \
# 0                                     NaN           NaN        NaN
# 1                                     NaN           NaN        NaN
# 2  [5c4cab8f-dfac-47de-bca4-3ca4d211f915]           NaN        NaN
# 3  [a3f9ce51-db7f-449a-902f-f4a595330b13]           NaN        NaN
# 4  [b7e37843-7498-42db-b117-ad4d40e0ed8c]  [60.0, 40.0]     3517.0
#
#     player_name  position_id              position_name  pass_recipient_id  \
# 0           NaN          NaN                        NaN                NaN
# 1           NaN          NaN                        NaN                NaN
# 2           NaN          NaN                        NaN                NaN
# 3           NaN          NaN                        NaN                NaN
# 4  Aaron Ramsey         19.0  Center Attacking Midfield             3086.0
#
#   pass_recipient_name  pass_length  pass_angle  pass_height_id  \
# 0                 NaN          NaN         NaN             NaN
# 1                 NaN          NaN         NaN             NaN
# 2                 NaN          NaN         NaN             NaN
# 3                 NaN          NaN         NaN             NaN
# 4          Ben Davies    26.075659   -2.693381             1.0
#
#   pass_height_name pass_end_location  pass_body_part_id pass_body_part_name  \
# 0              NaN               NaN                NaN                 NaN
# 1              NaN               NaN                NaN                 NaN
# 2              NaN               NaN                NaN                 NaN
# 3              NaN               NaN                NaN                 NaN
# 4      Ground Pass      [36.5, 28.7]               40.0          Right Foot
#
#    pass_type_id pass_type_name carry_end_location  pass_outcome_id  \
# 0           NaN            NaN                NaN              NaN
# 1           NaN            NaN                NaN              NaN
# 2           NaN            NaN                NaN              NaN
# 3           NaN            NaN                NaN              NaN
# 4          65.0       Kick Off                NaN              NaN
#
#   pass_outcome_name  ball_receipt_outcome_id ball_receipt_outcome_name  \
# 0               NaN                      NaN                       NaN
# 1               NaN                      NaN                       NaN
# 2               NaN                      NaN                       NaN
# 3               NaN                      NaN                       NaN
# 4               NaN                      NaN                       NaN
#
#   under_pressure  duel_type_id duel_type_name pass_aerial_won counterpress  \
# 0            NaN           NaN            NaN             NaN          NaN
# 1            NaN           NaN            NaN             NaN          NaN
# 2            NaN           NaN            NaN             NaN          NaN
# 3            NaN           NaN            NaN             NaN          NaN
# 4            NaN           NaN            NaN             NaN          NaN
#
#   pass_switch clearance_left_foot  clearance_body_part_id  \
# 0         NaN                 NaN                     NaN
# 1         NaN                 NaN                     NaN
# 2         NaN                 NaN                     NaN
# 3         NaN                 NaN                     NaN
# 4         NaN                 NaN                     NaN
#
#   clearance_body_part_name clearance_head clearance_aerial_won  out  \
# 0                      NaN            NaN                  NaN  NaN
# 1                      NaN            NaN                  NaN  NaN
# 2                      NaN            NaN                  NaN  NaN
# 3                      NaN            NaN                  NaN  NaN
# 4                      NaN            NaN                  NaN  NaN
#
#   pass_miscommunication dribble_overrun  dribble_outcome_id  \
# 0                   NaN             NaN                 NaN
# 1                   NaN             NaN                 NaN
# 2                   NaN             NaN                 NaN
# 3                   NaN             NaN                 NaN
# 4                   NaN             NaN                 NaN
#
#   dribble_outcome_name foul_won_defensive off_camera  duel_outcome_id  \
# 0                  NaN                NaN        NaN              NaN
# 1                  NaN                NaN        NaN              NaN
# 2                  NaN                NaN        NaN              NaN
# 3                  NaN                NaN        NaN              NaN
# 4                  NaN                NaN        NaN              NaN
#
#   duel_outcome_name  interception_outcome_id interception_outcome_name  \
# 0               NaN                      NaN                       NaN
# 1               NaN                      NaN                       NaN
# 2               NaN                      NaN                       NaN
# 3               NaN                      NaN                       NaN
# 4               NaN                      NaN                       NaN
#
#   pass_assisted_shot_id pass_shot_assist pass_through_ball  pass_technique_id  \
# 0                   NaN              NaN               NaN                NaN
# 1                   NaN              NaN               NaN                NaN
# 2                   NaN              NaN               NaN                NaN
# 3                   NaN              NaN               NaN                NaN
# 4                   NaN              NaN               NaN                NaN
#
#   pass_technique_name  shot_statsbomb_xg shot_end_location shot_key_pass_id  \
# 0                 NaN                NaN               NaN              NaN
# 1                 NaN                NaN               NaN              NaN
# 2                 NaN                NaN               NaN              NaN
# 3                 NaN                NaN               NaN              NaN
# 4                 NaN                NaN               NaN              NaN
#
#    shot_outcome_id shot_outcome_name shot_first_time  shot_technique_id  \
# 0              NaN               NaN             NaN                NaN
# 1              NaN               NaN             NaN                NaN
# 2              NaN               NaN             NaN                NaN
# 3              NaN               NaN             NaN                NaN
# 4              NaN               NaN             NaN                NaN
#
#   shot_technique_name  shot_body_part_id shot_body_part_name  shot_type_id  \
# 0                 NaN                NaN                 NaN           NaN
# 1                 NaN                NaN                 NaN           NaN
# 2                 NaN                NaN                 NaN           NaN
# 3                 NaN                NaN                 NaN           NaN
# 4                 NaN                NaN                 NaN           NaN
#
#   shot_type_name shot_freeze_frame  goalkeeper_technique_id  \
# 0            NaN               NaN                      NaN
# 1            NaN               NaN                      NaN
# 2            NaN               NaN                      NaN
# 3            NaN               NaN                      NaN
# 4            NaN               NaN                      NaN
#
#   goalkeeper_technique_name  goalkeeper_position_id goalkeeper_position_name  \
# 0                       NaN                     NaN                      NaN
# 1                       NaN                     NaN                      NaN
# 2                       NaN                     NaN                      NaN
# 3                       NaN                     NaN                      NaN
# 4                       NaN                     NaN                      NaN
#
#    goalkeeper_body_part_id goalkeeper_body_part_name  goalkeeper_type_id  \
# 0                      NaN                       NaN                 NaN
# 1                      NaN                       NaN                 NaN
# 2                      NaN                       NaN                 NaN
# 3                      NaN                       NaN                 NaN
# 4                      NaN                       NaN                 NaN
#
#   goalkeeper_type_name  goalkeeper_outcome_id goalkeeper_outcome_name  \
# 0                  NaN                    NaN                     NaN
# 1                  NaN                    NaN                     NaN
# 2                  NaN                    NaN                     NaN
# 3                  NaN                    NaN                     NaN
# 4                  NaN                    NaN                     NaN
#
#   miscontrol_aerial_won clearance_right_foot  foul_committed_type_id  \
# 0                   NaN                  NaN                     NaN
# 1                   NaN                  NaN                     NaN
# 2                   NaN                  NaN                     NaN
# 3                   NaN                  NaN                     NaN
# 4                   NaN                  NaN                     NaN
#
#   foul_committed_type_name pass_cross goalkeeper_end_location shot_one_on_one  \
# 0                      NaN        NaN                     NaN             NaN
# 1                      NaN        NaN                     NaN             NaN
# 2                      NaN        NaN                     NaN             NaN
# 3                      NaN        NaN                     NaN             NaN
# 4                      NaN        NaN                     NaN             NaN
#
#   shot_aerial_won foul_committed_advantage foul_won_advantage  \
# 0             NaN                      NaN                NaN
# 1             NaN                      NaN                NaN
# 2             NaN                      NaN                NaN
# 3             NaN                      NaN                NaN
# 4             NaN                      NaN                NaN
#
#   injury_stoppage_in_chain  50_50_outcome_id 50_50_outcome_name  \
# 0                      NaN               NaN                NaN
# 1                      NaN               NaN                NaN
# 2                      NaN               NaN                NaN
# 3                      NaN               NaN                NaN
# 4                      NaN               NaN                NaN
#
#    foul_committed_card_id foul_committed_card_name  substitution_outcome_id  \
# 0                     NaN                      NaN                      NaN
# 1                     NaN                      NaN                      NaN
# 2                     NaN                      NaN                      NaN
# 3                     NaN                      NaN                      NaN
# 4                     NaN                      NaN                      NaN
#
#   substitution_outcome_name  substitution_replacement_id  \
# 0                       NaN                          NaN
# 1                       NaN                          NaN
# 2                       NaN                          NaN
# 3                       NaN                          NaN
# 4                       NaN                          NaN
#
#   substitution_replacement_name dribble_nutmeg ball_recovery_offensive  \
# 0                           NaN            NaN                     NaN
# 1                           NaN            NaN                     NaN
# 2                           NaN            NaN                     NaN
# 3                           NaN            NaN                     NaN
# 4                           NaN            NaN                     NaN
#
#   pass_outswinging ball_recovery_recovery_failure pass_inswinging  \
# 0              NaN                            NaN             NaN
# 1              NaN                            NaN             NaN
# 2              NaN                            NaN             NaN
# 3              NaN                            NaN             NaN
# 4              NaN                            NaN             NaN
#
#   pass_no_touch pass_straight pass_goal_assist shot_deflected  \
# 0           NaN           NaN              NaN            NaN
# 1           NaN           NaN              NaN            NaN
# 2           NaN           NaN              NaN            NaN
# 3           NaN           NaN              NaN            NaN
# 4           NaN           NaN              NaN            NaN
#
#   block_deflection match_id
# 0              NaN  3857261
# 1              NaN  3857261
# 2              NaN  3857261
# 3              NaN  3857261
# 4              NaN  3857261

# %%
bool = (we['player_name'] == 'Danny Ward') & (we['type_name'] == 'Pass') & ((we['pass_body_part_name']  == 'Keeper Arm') | (we['pass_body_part_name'] == 'Drop Kick'))
passes_1st = we.loc[bool, ['pass_length', 'pass_angle', 'pass_end_location', 'player_name', 'pass_body_part_name']]
passes_1st.head(100)
# Out:
#       pass_length  pass_angle pass_end_location player_name  \
# 1597    10.220078   -0.639587      [16.6, 31.9]  Danny Ward
# 1713    68.406580   -0.162986      [83.9, 28.3]  Danny Ward
# 2522    24.407581   -0.753525      [32.5, 19.6]  Danny Ward
#
#      pass_body_part_name
# 1597          Keeper Arm
# 1713           Drop Kick
# 2522          Keeper Arm

# %%
pitch_width = 120
pitch_height = 80

fig, ax = createPitch(pitch_width, pitch_height, 'yards', 'gray')

for a_pass in passes_1st.iterrows():
    
    length = a_pass[1][0]
    angle = a_pass[1][1]
    x = a_pass[1][2][0]
    y = a_pass[1][2][1]
    if (np.pi/2) > angle > 0:
        x_offset = np.around(np.cos(angle) * length, 1)
        y_offset = np.around(np.sin(angle) * length, 1)
        plt.arrow(x-x_offset, y-y_offset, x_offset, y_offset, color='red', head_width=3, head_length=3)
    elif (np.pi) > angle > (np.pi/2):
        angle = angle - np.pi/2
        x_offset = np.around(np.sin(angle) * length, 1)
        y_offset = np.around(np.cos(angle) * length, 1)
        plt.arrow(x-x_offset, y-y_offset, x_offset, y_offset, color='blue', head_width=3, head_length=3)
    elif (-np.pi/2) < angle < 0:
        angle = -angle
        x_offset = np.around(np.cos(angle) * length, 1)
        y_offset = np.around(np.sin(angle) * length, 1)
        plt.arrow(x-x_offset, y+y_offset, +x_offset, -y_offset, color='green', head_width=3, head_length=3)
    else:
        angle = -(angle - np.pi/2)
        x_offset = np.around(np.sin(angle) * length, 1)
        y_offset = np.around(np.cos(angle) * length, 1)
        plt.arrow(x-x_offset, y+y_offset, x_offset, -y_offset, color='orange', head_width=3, head_length=3)
