# %% [markdown]
# # Performing iterative operations in pandas

# %%
import pandas as pd
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
bike_data = pd.read_csv('data/bk_daily.csv')

# %%
bike_data.head()
# Out:
#    instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0        1  2011-01-01       1   0     1        0        6           0
# 1        2  2011-01-02       1   0     1        0        0           0
# 2        3  2011-01-03       1   0     1        0        1           1
# 3        4  2011-01-04       1   0     1        0        2           1
# 4        5  2011-01-05       1   0     1        0        3           1
#
#    weathersit      temp     atemp       hum  windspeed  casual  registered  \
# 0           2  0.344167  0.363625  0.805833   0.160446     331         654
# 1           2  0.363478  0.353739  0.696087   0.248539     131         670
# 2           1  0.196364  0.189405  0.437273   0.248309     120        1229
# 3           1  0.200000  0.212122  0.590435   0.160296     108        1454
# 4           1  0.226957  0.229270  0.436957   0.186900      82        1518
#
#     cnt
# 0   985
# 1   801
# 2  1349
# 3  1562
# 4  1600

# %%
# Not the fastest way
for index, row in bike_data.iterrows():
    if row['cnt'] > 8500:
        print(index, row['dteday'], row['cnt'])
# Out:
# 623 2012-09-15 8714
# 637 2012-09-29 8555

# %%
def get_average_temperature(row, col1, col2):
    return (row[col1] + row[col2]) / 2

# %%
# Incorrect way to modify df, you should never modify a dataframe you are iterating over (as it may br returning a
# copy instead of a view)
for index, row in bike_data.iterrows():
    row['avgtemp'] = get_average_temperature(row, 'temp', 'atemp')

# %%
bike_data.head()
# Out:
#    instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0        1  2011-01-01       1   0     1        0        6           0
# 1        2  2011-01-02       1   0     1        0        0           0
# 2        3  2011-01-03       1   0     1        0        1           1
# 3        4  2011-01-04       1   0     1        0        2           1
# 4        5  2011-01-05       1   0     1        0        3           1
#
#    weathersit      temp     atemp       hum  windspeed  casual  registered  \
# 0           2  0.344167  0.363625  0.805833   0.160446     331         654
# 1           2  0.363478  0.353739  0.696087   0.248539     131         670
# 2           1  0.196364  0.189405  0.437273   0.248309     120        1229
# 3           1  0.200000  0.212122  0.590435   0.160296     108        1454
# 4           1  0.226957  0.229270  0.436957   0.186900      82        1518
#
#     cnt
# 0   985
# 1   801
# 2  1349
# 3  1562
# 4  1600

# %%
def slow_method(data):
    # As it returns a copy need to save it
    new_data = pd.DataFrame(columns=list(data))
    for index, row in data.iterrows():
        row['avgtemp'] = get_average_temperature(row, 'temp', 'atemp')
        new_data = new_data.append(row)
    return new_data

# %%
timeit_res = %timeit -o slow_method(bike_data)
# Out:
# 488 ms ± 1.28 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
timeit_res
# Out:
# <TimeitResult : 488 ms ± 1.28 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)>

# %%
new_data = slow_method(bike_data)
new_data.head()
# Out:
#   instant      dteday season yr mnth holiday weekday workingday weathersit  \
# 0       1  2011-01-01      1  0    1       0       6          0          2
# 1       2  2011-01-02      1  0    1       0       0          0          2
# 2       3  2011-01-03      1  0    1       0       1          1          1
# 3       4  2011-01-04      1  0    1       0       2          1          1
# 4       5  2011-01-05      1  0    1       0       3          1          1
#
#        temp     atemp       hum  windspeed casual registered   cnt   avgtemp
# 0  0.344167  0.363625  0.805833   0.160446    331        654   985  0.353896
# 1  0.363478  0.353739  0.696087   0.248539    131        670   801  0.358608
# 2  0.196364  0.189405  0.437273   0.248309    120       1229  1349  0.192885
# 3  0.200000  0.212122  0.590435   0.160296    108       1454  1562  0.206061
# 4  0.226957  0.229270  0.436957   0.186900     82       1518  1600  0.228113

# %%
bike_data['avg_temp_apply'] = bike_data.apply(lambda x: get_average_temperature(x, 'temp', 'atemp'), axis=1)

# %%
bike_data.sample(5)
# Out:
#      instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 418      419  2012-02-23       1   1     2        0        4           1
# 310      311  2011-11-07       4   0    11        0        1           1
# 523      524  2012-06-07       2   1     6        0        4           1
# 114      115  2011-04-25       2   0     4        0        1           1
# 657      658  2012-10-19       4   1    10        0        5           1
#
#      weathersit      temp     atemp       hum  windspeed  casual  registered  \
# 418           1  0.454167  0.444446  0.554583   0.190913     516        4546
# 310           1  0.395000  0.400871  0.758750   0.057225     373        3662
# 523           1  0.602500  0.569442  0.567083   0.157350    1038        6456
# 114           1  0.606667  0.574500  0.776667   0.185333     773        3300
# 657           2  0.563333  0.537896  0.815000   0.134954     753        4671
#
#       cnt  avg_temp_apply
# 418  5062        0.449306
# 310  4035        0.397935
# 523  7494        0.585971
# 114  4073        0.590583
# 657  5424        0.550615

# %%
# %timeit bike_data.apply(lambda x: get_average_temperature(x, 'temp', 'atemp'), axis=1)
# Out:
# 2.21 ms ± 27.5 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
# Faster than iterrows, can use column indicies or getattr function
for row in bike_data.itertuples():
    if row[16] > 8500:
        print(row[0], row[2], row[16])
        print(getattr(row, 'Index'), getattr(row, 'dteday'), getattr(row, 'cnt'))
# Out:
# 623 2012-09-15 8714
# 623 2012-09-15 8714
# 637 2012-09-29 8555
# 637 2012-09-29 8555

# %% [markdown]
# # Evaluating expressions in pandas

# %%
data = pd.read_csv('data/bk_daily.csv')

# %%
def eval_average_temperature(data):
    new_df = pd.DataFrame(columns=list(data))
    for _, row in data.iterrows():
        row['average_temperature'] = pd.eval("(row['temp']+row['atemp'])/2", engine='python')
        new_df = new_df.append(row)
    return new_df

# %%
new_data = eval_average_temperature(data)

# %%
new_data.head()
# Out:
#   instant      dteday season yr mnth holiday weekday workingday weathersit  \
# 0       1  2011-01-01      1  0    1       0       6          0          2
# 1       2  2011-01-02      1  0    1       0       0          0          2
# 2       3  2011-01-03      1  0    1       0       1          1          1
# 3       4  2011-01-04      1  0    1       0       2          1          1
# 4       5  2011-01-05      1  0    1       0       3          1          1
#
#        temp     atemp       hum  windspeed casual registered   cnt  \
# 0  0.344167  0.363625  0.805833   0.160446    331        654   985
# 1  0.363478  0.353739  0.696087   0.248539    131        670   801
# 2  0.196364  0.189405  0.437273   0.248309    120       1229  1349
# 3  0.200000  0.212122  0.590435   0.160296    108       1454  1562
# 4  0.226957  0.229270  0.436957   0.186900     82       1518  1600
#
#    average_temperature
# 0             0.353896
# 1             0.358608
# 2             0.192885
# 3             0.206061
# 4             0.228113

# %%
filtered_data = data.query('cnt > 5000')
filtered_data.head()
# Out:
#      instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 119      120  2011-04-30       2   0     4        0        6           0
# 140      141  2011-05-21       2   0     5        0        6           0
# 153      154  2011-06-03       2   0     6        0        5           1
# 154      155  2011-06-04       2   0     6        0        6           0
# 163      164  2011-06-13       2   0     6        0        1           1
#
#      weathersit    temp     atemp       hum  windspeed  casual  registered  \
# 119           1  0.4725  0.464021  0.503333   0.235075    1965        3347
# 140           1  0.6025  0.571975  0.626667   0.120650    2258        3547
# 153           1  0.6200  0.587133  0.354167   0.253121     898        4414
# 154           1  0.6350  0.594696  0.456250   0.123142    1869        3473
# 163           1  0.6350  0.601654  0.494583   0.305350     863        4157
#
#       cnt
# 119  5312
# 140  5805
# 153  5312
# 154  5342
# 163  5020

# %%
condition = 5000
filtered_data = data.query('cnt > @condition')
filtered_data.head()
# Out:
#      instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 119      120  2011-04-30       2   0     4        0        6           0
# 140      141  2011-05-21       2   0     5        0        6           0
# 153      154  2011-06-03       2   0     6        0        5           1
# 154      155  2011-06-04       2   0     6        0        6           0
# 163      164  2011-06-13       2   0     6        0        1           1
#
#      weathersit    temp     atemp       hum  windspeed  casual  registered  \
# 119           1  0.4725  0.464021  0.503333   0.235075    1965        3347
# 140           1  0.6025  0.571975  0.626667   0.120650    2258        3547
# 153           1  0.6200  0.587133  0.354167   0.253121     898        4414
# 154           1  0.6350  0.594696  0.456250   0.123142    1869        3473
# 163           1  0.6350  0.601654  0.494583   0.305350     863        4157
#
#       cnt
# 119  5312
# 140  5805
# 153  5312
# 154  5342
# 163  5020

# %%
condition01 = 0.5
filtered_data01 = data.query('cnt > @condition & temp > 0.5')
filtered_data01.head()
# Out:
#      instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 140      141  2011-05-21       2   0     5        0        6           0
# 153      154  2011-06-03       2   0     6        0        5           1
# 154      155  2011-06-04       2   0     6        0        6           0
# 163      164  2011-06-13       2   0     6        0        1           1
# 165      166  2011-06-15       2   0     6        0        3           1
#
#      weathersit      temp     atemp       hum  windspeed  casual  registered  \
# 140           1  0.602500  0.571975  0.626667   0.120650    2258        3547
# 153           1  0.620000  0.587133  0.354167   0.253121     898        4414
# 154           1  0.635000  0.594696  0.456250   0.123142    1869        3473
# 163           1  0.635000  0.601654  0.494583   0.305350     863        4157
# 165           1  0.626667  0.587754  0.471667   0.167912     769        4411
#
#       cnt
# 140  5805
# 153  5312
# 154  5342
# 163  5020
# 165  5180

# %%
# denotes spring or summer
season = [2,3]
season_filter = data.query('season == @season')

# %%
# Shows all the outputs are either 2, 3 matching the condition
season_filter['season'].drop_duplicates().to_list()
# Out:
# [2, 3]

# %% [markdown]
# # Time series analysis in pandas

# %%
data = pd.read_csv('data/bk_daily.csv')

# %%
import matplotlib.pyplot as plt

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 731 entries, 0 to 730
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     731 non-null    int64
#  1   dteday      731 non-null    object
#  2   season      731 non-null    int64
#  3   yr          731 non-null    int64
#  4   mnth        731 non-null    int64
#  5   holiday     731 non-null    int64
#  6   weekday     731 non-null    int64
#  7   workingday  731 non-null    int64
#  8   weathersit  731 non-null    int64
#  9   temp        731 non-null    float64
#  10  atemp       731 non-null    float64
#  11  hum         731 non-null    float64
#  12  windspeed   731 non-null    float64
#  13  casual      731 non-null    int64
#  14  registered  731 non-null    int64
#  15  cnt         731 non-null    int64
# dtypes: float64(4), int64(11), object(1)
# memory usage: 91.5+ KB

# %%
data.shape
# Out:
# (731, 16)

# %%
data['dteday'] = data[['dteday']].apply(lambda x: pd.to_datetime(x))

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 731 entries, 0 to 730
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     731 non-null    int64
#  1   dteday      731 non-null    datetime64[ns]
#  2   season      731 non-null    int64
#  3   yr          731 non-null    int64
#  4   mnth        731 non-null    int64
#  5   holiday     731 non-null    int64
#  6   weekday     731 non-null    int64
#  7   workingday  731 non-null    int64
#  8   weathersit  731 non-null    int64
#  9   temp        731 non-null    float64
#  10  atemp       731 non-null    float64
#  11  hum         731 non-null    float64
#  12  windspeed   731 non-null    float64
#  13  casual      731 non-null    int64
#  14  registered  731 non-null    int64
#  15  cnt         731 non-null    int64
# dtypes: datetime64[ns](1), float64(4), int64(11)
# memory usage: 91.5 KB

# %%
data.set_index('dteday', inplace=True)
data.head()
# Out:
#             instant  season  yr  mnth  holiday  weekday  workingday  \
# dteday
# 2011-01-01        1       1   0     1        0        6           0
# 2011-01-02        2       1   0     1        0        0           0
# 2011-01-03        3       1   0     1        0        1           1
# 2011-01-04        4       1   0     1        0        2           1
# 2011-01-05        5       1   0     1        0        3           1
#
#             weathersit      temp     atemp       hum  windspeed  casual  \
# dteday
# 2011-01-01           2  0.344167  0.363625  0.805833   0.160446     331
# 2011-01-02           2  0.363478  0.353739  0.696087   0.248539     131
# 2011-01-03           1  0.196364  0.189405  0.437273   0.248309     120
# 2011-01-04           1  0.200000  0.212122  0.590435   0.160296     108
# 2011-01-05           1  0.226957  0.229270  0.436957   0.186900      82
#
#             registered   cnt
# dteday
# 2011-01-01         654   985
# 2011-01-02         670   801
# 2011-01-03        1229  1349
# 2011-01-04        1454  1562
# 2011-01-05        1518  1600

# %%
def daily_change(row):
    return row.pct_change()

# %%
data['casual_pct'] = data[['casual']].apply(lambda x: daily_change(x))
data['regular_pct'] = data[['registered']].apply(lambda x: daily_change(x))
data.head()
# Out:
#             instant  season  yr  mnth  holiday  weekday  workingday  \
# dteday
# 2011-01-01        1       1   0     1        0        6           0
# 2011-01-02        2       1   0     1        0        0           0
# 2011-01-03        3       1   0     1        0        1           1
# 2011-01-04        4       1   0     1        0        2           1
# 2011-01-05        5       1   0     1        0        3           1
#
#             weathersit      temp     atemp       hum  windspeed  casual  \
# dteday
# 2011-01-01           2  0.344167  0.363625  0.805833   0.160446     331
# 2011-01-02           2  0.363478  0.353739  0.696087   0.248539     131
# 2011-01-03           1  0.196364  0.189405  0.437273   0.248309     120
# 2011-01-04           1  0.200000  0.212122  0.590435   0.160296     108
# 2011-01-05           1  0.226957  0.229270  0.436957   0.186900      82
#
#             registered   cnt  casual_pct  regular_pct
# dteday
# 2011-01-01         654   985         NaN          NaN
# 2011-01-02         670   801   -0.604230     0.024465
# 2011-01-03        1229  1349   -0.083969     0.834328
# 2011-01-04        1454  1562   -0.100000     0.183076
# 2011-01-05        1518  1600   -0.240741     0.044017

# %%
# Secondary y gives an alternative axis for regular_pct, not that useful with this graph imo
data.loc['2011-01-01':'2011-12-31', ['casual_pct', 'regular_pct']].plot(
    secondary_y=['regular_pct'],
    mark_right=False,
    grid=True,
    figsize=(10,8)
)
plt.show()

# %%
data['cnt_diff'] = data['cnt'].diff()

# %%
data[['cnt','cnt_diff']].head(10)
# Out:
#              cnt  cnt_diff
# dteday
# 2011-01-01   985       NaN
# 2011-01-02   801    -184.0
# 2011-01-03  1349     548.0
# 2011-01-04  1562     213.0
# 2011-01-05  1600      38.0
# 2011-01-06  1606       6.0
# 2011-01-07  1510     -96.0
# 2011-01-08   959    -551.0
# 2011-01-09   822    -137.0
# 2011-01-10  1321     499.0

# %%
data['cnt_diff_n'] = data['cnt'].diff(periods=5)
data[['cnt','cnt_diff','cnt_diff_n']].head(10)
# Out:
#              cnt  cnt_diff  cnt_diff_n
# dteday
# 2011-01-01   985       NaN         NaN
# 2011-01-02   801    -184.0         NaN
# 2011-01-03  1349     548.0         NaN
# 2011-01-04  1562     213.0         NaN
# 2011-01-05  1600      38.0         NaN
# 2011-01-06  1606       6.0       621.0
# 2011-01-07  1510     -96.0       709.0
# 2011-01-08   959    -551.0      -390.0
# 2011-01-09   822    -137.0      -740.0
# 2011-01-10  1321     499.0      -279.0

# %%
data['cnt_diff_following'] = data['cnt'].diff(periods=-1)
data[['cnt','cnt_diff','cnt_diff_n','cnt_diff_following']].tail(10)
# Out:
#              cnt  cnt_diff  cnt_diff_n  cnt_diff_following
# dteday
# 2012-12-22  1749   -1874.0     -2836.0               -38.0
# 2012-12-23  1787      38.0     -3770.0               867.0
# 2012-12-24   920    -867.0     -4347.0               -93.0
# 2012-12-25  1013      93.0     -3115.0               572.0
# 2012-12-26   441    -572.0     -3182.0             -1673.0
# 2012-12-27  2114    1673.0       365.0              -981.0
# 2012-12-28  3095     981.0      1308.0              1754.0
# 2012-12-29  1341   -1754.0       421.0              -455.0
# 2012-12-30  1796     455.0       783.0              -933.0
# 2012-12-31  2729     933.0      2288.0                 NaN

# %%
data['ma_5'] = data['cnt'].rolling(window=5).mean()
data['ma_20'] = data['cnt'].rolling(window=20).mean()
data['ma_50'] = data['cnt'].rolling(window=50).mean()

# %%
data['ma_5'].plot(figsize=(10,8))
data['ma_20'].plot(figsize=(10,8))
data['ma_50'].plot(figsize=(10,8))
plt.legend()
plt.show()

# %%
pd.date_range(start='2020/01/01', end='2020/01/10')
# Out:
# DatetimeIndex(['2020-01-01', '2020-01-02', '2020-01-03', '2020-01-04',
#                '2020-01-05', '2020-01-06', '2020-01-07', '2020-01-08',
#                '2020-01-09', '2020-01-10'],
#               dtype='datetime64[ns]', freq='D')
