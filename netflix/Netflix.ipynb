# %%
import pandas as pd

# %%
netflix = pd.read_csv('ViewingActivity-sample.csv')

# %%
type(netflix)
# Out:
# pandas.core.frame.DataFrame

# %%
netflix.shape
# Out:
# (200, 10)

# %%
netflix.sample()
# Out:
#   Profile Name          Start Time Duration  Attributes  \
# 1      Charlie  2013-03-20 4:27:45  0:44:31         NaN
#
#                                                Title  Supplemental Video Type  \
# 1  Star Trek: Deep Space Nine: Season 5: Blaze of...                      NaN
#
#   Device Type Bookmark  Latest Bookmark             Country
# 1         Mac  0:44:31  Not latest view  US (United States)

# %%
netflix.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 10 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Profile Name             200 non-null    object
#  1   Start Time               200 non-null    object
#  2   Duration                 200 non-null    object
#  3   Attributes               0 non-null      float64
#  4   Title                    200 non-null    object
#  5   Supplemental Video Type  0 non-null      float64
#  6   Device Type              200 non-null    object
#  7   Bookmark                 200 non-null    object
#  8   Latest Bookmark          200 non-null    object
#  9   Country                  200 non-null    object
# dtypes: float64(2), object(8)
# memory usage: 15.8+ KB

# %%
netflix.loc[5, "Bookmark"]
# Out:
# '0:22:31'

# %%
netflix[['Start Time']].value_counts()
# Out:
# Start Time
# 2013-03-01 20:47:09    1
# 2013-03-14 23:36:27    1
# 2013-03-13 3:46:53     1
# 2013-03-13 3:52:19     1
# 2013-03-13 4:13:19     1
#                       ..
# 2013-03-10 20:14:39    1
# 2013-03-10 20:42:49    1
# 2013-03-10 21:02:07    1
# 2013-03-10 21:25:01    1
# 2013-03-20 5:17:53     1
# Length: 200, dtype: int64

# %%
netflix.loc[0:5]
# Out:
#   Profile Name           Start Time Duration  Attributes  \
# 0      Charlie   2013-03-20 5:17:53  0:00:05         NaN
# 1      Charlie   2013-03-20 4:27:45  0:44:31         NaN
# 2      Charlie   2013-03-20 4:05:21  0:22:06         NaN
# 3      Charlie   2013-03-20 0:20:03  0:48:14         NaN
# 4      Charlie   2013-03-20 0:10:31  0:04:51         NaN
# 5      Charlie  2013-03-19 22:34:08  0:22:29         NaN
#
#                                                Title  Supplemental Video Type  \
# 0  Star Trek: Deep Space Nine: Season 5: Empok No...                      NaN
# 1  Star Trek: Deep Space Nine: Season 5: Blaze of...                      NaN
# 2  Star Trek: Deep Space Nine: Season 5: Children...                      NaN
# 3                                  The Invisible War                      NaN
# 4                                  The Invisible War                      NaN
# 5  Star Trek: Deep Space Nine: Season 5: Children...                      NaN
#
# ...

# %%
netflix.head(5)
# Out:
#   Profile Name          Start Time Duration  Attributes  \
# 0      Charlie  2013-03-20 5:17:53  0:00:05         NaN
# 1      Charlie  2013-03-20 4:27:45  0:44:31         NaN
# 2      Charlie  2013-03-20 4:05:21  0:22:06         NaN
# 3      Charlie  2013-03-20 0:20:03  0:48:14         NaN
# 4      Charlie  2013-03-20 0:10:31  0:04:51         NaN
#
#                                                Title  Supplemental Video Type  \
# 0  Star Trek: Deep Space Nine: Season 5: Empok No...                      NaN
# 1  Star Trek: Deep Space Nine: Season 5: Blaze of...                      NaN
# 2  Star Trek: Deep Space Nine: Season 5: Children...                      NaN
# 3                                  The Invisible War                      NaN
# 4                                  The Invisible War                      NaN
#
#           Device Type Bookmark  Latest Bookmark             Country
# 0                 Mac  0:00:05  Not latest view  US (United States)
# ...

# %%
netflix["Device Type"].value_counts()
# Out:
# Mac                         175
# Microsoft Xbox 360           18
# Apple iPhone 5 with CDMA      7
# Name: Device Type, dtype: int64

# %%
tvc = netflix["Title"].value_counts()

# %%
type(tvc)
# Out:
# pandas.core.series.Series

# %%
print(tvc)
# Out:
# The Office (U.S.): Season 3: Grief Counseling (Episode 4)           4
# The Office (U.S.): Season 3: A Benihana Christmas (Episode 10)      4
# The Office (U.S.): Season 4: Launch Party (Episode 3)               4
